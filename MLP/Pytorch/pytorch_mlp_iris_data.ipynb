# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import torch 
import tensorflow as tf

# %%
data=pd.read_csv('IRIS.csv')
#data=pd.get_dummies(data,columns=['species'])
df=data
species = dict(zip(list(df['species'].unique()), ([0, 1, 2])))
df['species'].replace(species,inplace=True)

y=df.pop('species')
x=df.values

# %%
X_torch=torch.tensor(x,dtype=torch.float32)
y_torch=torch.tensor(y,dtype=torch.long)

# %%
class MLPTorch(torch.nn.Module):
    def __init__(self,input_dim,units=32,num_class=3):
        super(MLPTorch,self).__init__()
        self.linear1=torch.nn.Linear(input_dim,units)
        self.linear2=torch.nn.Linear(units,64)
        self.linear3=torch.nn.Linear(64,32)
        self.linear4=torch.nn.Linear(32,num_class)
        self.relu=torch.nn.ReLU()
        self.softmax=torch.nn.Softmax()
    def __call__(self,xb):
        l1=self.linear1(xb)
        r1=self.relu(l1)
        l2=self.linear2(r1)
        r2=self.relu(l2)
        l3=self.linear3(r2)
        r3=self.relu(l3)
        l4=self.linear4(r3)
        out=self.softmax(l4)
        return out    
    def calc_accuracy(self,y_pred,y_torch):

        return (torch.argmax(y_pred,dim=1)==y_torch).float().sum()/len(y_torch)

# %%
model=MLPTorch(X_torch.shape[1],units=32,num_class=3)
criterion=torch.nn.CrossEntropyLoss()
optimizer=torch.optim.Adam(model.parameters(),lr=0.01)

# %%
for epoch in range(200):
    y_pred=model(X_torch)
    loss_function=criterion(y_pred,y_torch)
    optimizer.zero_grad()
    loss_function.backward()
    optimizer.step()
    acc=model.calc_accuracy(y_pred,y_torch)
    print("after {} epoch, loss ={:.4f} and accuracy is {:.4f}".format(epoch,loss_function.detach().numpy(),acc))
# Out:
# /tmp/ipykernel_20894/3850486144.py:18: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out=self.softmax(l4)
# after 0 epoch, loss =1.0918 and accuracy is 0.3333
# after 1 epoch, loss =1.0680 and accuracy is 0.3333
# after 2 epoch, loss =1.0507 and accuracy is 0.3333
# after 3 epoch, loss =1.0278 and accuracy is 0.3333
# after 4 epoch, loss =0.9956 and accuracy is 0.6600
# after 5 epoch, loss =0.9645 and accuracy is 0.6667
# after 6 epoch, loss =0.9273 and accuracy is 0.6667
# after 7 epoch, loss =0.8812 and accuracy is 0.6867
# after 8 epoch, loss =0.8350 and accuracy is 0.8667
# after 9 epoch, loss =0.7875 and accuracy is 0.8467
# after 10 epoch, loss =0.7515 and accuracy is 0.9733
# after 11 epoch, loss =0.7204 and accuracy is 0.9133
# after 12 epoch, loss =0.6931 and accuracy is 0.9533
# after 13 epoch, loss =0.6725 and accuracy is 0.9533
# after 14 epoch, loss =0.6569 and accuracy is 0.9533
# after 15 epoch, loss =0.6467 and accuracy is 0.9333
# after 16 epoch, loss =0.6305 and accuracy is 0.9533
# after 17 epoch, loss =0.6153 and accuracy is 0.9800
# after 18 epoch, loss =0.6096 and accuracy is 0.9733
# after 19 epoch, loss =0.6074 and accuracy is 0.9533
# after 20 epoch, loss =0.5997 and accuracy is 0.9733
# after 21 epoch, loss =0.5934 and accuracy is 0.9800
# after 22 epoch, loss =0.5938 and accuracy is 0.9533
# after 23 epoch, loss =0.5904 and accuracy is 0.9733
# after 24 epoch, loss =0.5858 and accuracy is 0.9800
# after 25 epoch, loss =0.5870 and accuracy is 0.9667
# after 26 epoch, loss =0.5849 and accuracy is 0.9733
# after 27 epoch, loss =0.5814 and accuracy is 0.9800
# after 28 epoch, loss =0.5831 and accuracy is 0.9800
# after 29 epoch, loss =0.5816 and accuracy is 0.9733
# after 30 epoch, loss =0.5786 and accuracy is 0.9800
# after 31 epoch, loss =0.5810 and accuracy is 0.9800
# after 32 epoch, loss =0.5798 and accuracy is 0.9733
# after 33 epoch, loss =0.5768 and accuracy is 0.9800
# after 34 epoch, loss =0.5806 and accuracy is 0.9733
# after 35 epoch, loss =0.5790 and accuracy is 0.9733
# after 36 epoch, loss =0.5762 and accuracy is 0.9733
# after 37 epoch, loss =0.5817 and accuracy is 0.9600
# after 38 epoch, loss =0.5774 and accuracy is 0.9733
# after 39 epoch, loss =0.5767 and accuracy is 0.9733
# after 40 epoch, loss =0.5793 and accuracy is 0.9733
# after 41 epoch, loss =0.5745 and accuracy is 0.9800
# after 42 epoch, loss =0.5753 and accuracy is 0.9733
# after 43 epoch, loss =0.5752 and accuracy is 0.9800
# after 44 epoch, loss =0.5729 and accuracy is 0.9867
# after 45 epoch, loss =0.5735 and accuracy is 0.9800
# after 46 epoch, loss =0.5732 and accuracy is 0.9867
# after 47 epoch, loss =0.5722 and accuracy is 0.9867
# after 48 epoch, loss =0.5725 and accuracy is 0.9800
# after 49 epoch, loss =0.5723 and accuracy is 0.9867
# after 50 epoch, loss =0.5717 and accuracy is 0.9867
# after 51 epoch, loss =0.5717 and accuracy is 0.9800
# after 52 epoch, loss =0.5717 and accuracy is 0.9867
# after 53 epoch, loss =0.5714 and accuracy is 0.9867
# after 54 epoch, loss =0.5712 and accuracy is 0.9867
# after 55 epoch, loss =0.5712 and accuracy is 0.9867
# after 56 epoch, loss =0.5711 and accuracy is 0.9800
# after 57 epoch, loss =0.5708 and accuracy is 0.9867
# after 58 epoch, loss =0.5709 and accuracy is 0.9867
# after 59 epoch, loss =0.5709 and accuracy is 0.9800
# after 60 epoch, loss =0.5705 and accuracy is 0.9867
# after 61 epoch, loss =0.5705 and accuracy is 0.9867
# after 62 epoch, loss =0.5706 and accuracy is 0.9800
# after 63 epoch, loss =0.5703 and accuracy is 0.9867
# after 64 epoch, loss =0.5702 and accuracy is 0.9867
# after 65 epoch, loss =0.5702 and accuracy is 0.9800
# after 66 epoch, loss =0.5701 and accuracy is 0.9867
# after 67 epoch, loss =0.5700 and accuracy is 0.9800
# after 68 epoch, loss =0.5698 and accuracy is 0.9867
# after 69 epoch, loss =0.5698 and accuracy is 0.9867
# after 70 epoch, loss =0.5698 and accuracy is 0.9800
# after 71 epoch, loss =0.5697 and accuracy is 0.9867
# after 72 epoch, loss =0.5697 and accuracy is 0.9800
# after 73 epoch, loss =0.5695 and accuracy is 0.9867
# after 74 epoch, loss =0.5694 and accuracy is 0.9800
# after 75 epoch, loss =0.5694 and accuracy is 0.9800
# after 76 epoch, loss =0.5693 and accuracy is 0.9867
# after 77 epoch, loss =0.5693 and accuracy is 0.9800
# after 78 epoch, loss =0.5693 and accuracy is 0.9867
# after 79 epoch, loss =0.5694 and accuracy is 0.9800
# after 80 epoch, loss =0.5694 and accuracy is 0.9867
# after 81 epoch, loss =0.5697 and accuracy is 0.9800
# after 82 epoch, loss =0.5693 and accuracy is 0.9867
# after 83 epoch, loss =0.5692 and accuracy is 0.9800
# after 84 epoch, loss =0.5691 and accuracy is 0.9867
# after 85 epoch, loss =0.5693 and accuracy is 0.9800
# after 86 epoch, loss =0.5693 and accuracy is 0.9933
# after 87 epoch, loss =0.5701 and accuracy is 0.9800
# after 88 epoch, loss =0.5688 and accuracy is 0.9867
# after 89 epoch, loss =0.5689 and accuracy is 0.9933
# after 90 epoch, loss =0.5704 and accuracy is 0.9800
# after 91 epoch, loss =0.5687 and accuracy is 0.9867
# after 92 epoch, loss =0.5691 and accuracy is 0.9933
# after 93 epoch, loss =0.5722 and accuracy is 0.9800
# after 94 epoch, loss =0.5697 and accuracy is 0.9800
# after 95 epoch, loss =0.5831 and accuracy is 0.9667
# after 96 epoch, loss =0.5924 and accuracy is 0.9600
# after 97 epoch, loss =0.6022 and accuracy is 0.9533
# after 98 epoch, loss =0.5753 and accuracy is 0.9800
# after 99 epoch, loss =0.6138 and accuracy is 0.9333
# after 100 epoch, loss =0.6143 and accuracy is 0.9333
# after 101 epoch, loss =0.5702 and accuracy is 0.9800
# after 102 epoch, loss =0.5865 and accuracy is 0.9600
# after 103 epoch, loss =0.5748 and accuracy is 0.9800
# after 104 epoch, loss =0.5830 and accuracy is 0.9667
# after 105 epoch, loss =0.5722 and accuracy is 0.9800
# after 106 epoch, loss =0.5792 and accuracy is 0.9667
# after 107 epoch, loss =0.5691 and accuracy is 0.9800
# after 108 epoch, loss =0.5969 and accuracy is 0.9467
# after 109 epoch, loss =0.5704 and accuracy is 0.9800
# after 110 epoch, loss =0.5804 and accuracy is 0.9667
# after 111 epoch, loss =0.5716 and accuracy is 0.9800
# after 112 epoch, loss =0.5783 and accuracy is 0.9733
# after 113 epoch, loss =0.5712 and accuracy is 0.9800
# after 114 epoch, loss =0.5760 and accuracy is 0.9800
# after 115 epoch, loss =0.5704 and accuracy is 0.9800
# after 116 epoch, loss =0.5783 and accuracy is 0.9733
# after 117 epoch, loss =0.5714 and accuracy is 0.9800
# after 118 epoch, loss =0.5772 and accuracy is 0.9800
# after 119 epoch, loss =0.5707 and accuracy is 0.9800
# after 120 epoch, loss =0.5772 and accuracy is 0.9733
# after 121 epoch, loss =0.5703 and accuracy is 0.9800
# after 122 epoch, loss =0.5738 and accuracy is 0.9800
# after 123 epoch, loss =0.5711 and accuracy is 0.9800
# after 124 epoch, loss =0.5693 and accuracy is 0.9867
# after 125 epoch, loss =0.5681 and accuracy is 0.9933
# after 126 epoch, loss =0.5695 and accuracy is 0.9800
# after 127 epoch, loss =0.5688 and accuracy is 0.9800
# after 128 epoch, loss =0.5701 and accuracy is 0.9867
# after 129 epoch, loss =0.5691 and accuracy is 0.9800
# after 130 epoch, loss =0.5695 and accuracy is 0.9800
# after 131 epoch, loss =0.5680 and accuracy is 0.9867
# after 132 epoch, loss =0.5685 and accuracy is 0.9867
# after 133 epoch, loss =0.5696 and accuracy is 0.9800
# after 134 epoch, loss =0.5695 and accuracy is 0.9800
# after 135 epoch, loss =0.5683 and accuracy is 0.9867
# after 136 epoch, loss =0.5678 and accuracy is 0.9933
# after 137 epoch, loss =0.5686 and accuracy is 0.9800
# after 138 epoch, loss =0.5677 and accuracy is 0.9867
# after 139 epoch, loss =0.5693 and accuracy is 0.9867
# after 140 epoch, loss =0.5699 and accuracy is 0.9800
# after 141 epoch, loss =0.5706 and accuracy is 0.9800
# after 142 epoch, loss =0.5678 and accuracy is 0.9800
# after 143 epoch, loss =0.5753 and accuracy is 0.9733
# after 144 epoch, loss =0.5724 and accuracy is 0.9800
# after 145 epoch, loss =0.5814 and accuracy is 0.9667
# after 146 epoch, loss =0.5710 and accuracy is 0.9800
# after 147 epoch, loss =0.5785 and accuracy is 0.9733
# after 148 epoch, loss =0.5692 and accuracy is 0.9800
# after 149 epoch, loss =0.5719 and accuracy is 0.9800
# after 150 epoch, loss =0.5709 and accuracy is 0.9800
# after 151 epoch, loss =0.5675 and accuracy is 0.9867
# after 152 epoch, loss =0.5739 and accuracy is 0.9733
# after 153 epoch, loss =0.5723 and accuracy is 0.9800
# after 154 epoch, loss =0.5812 and accuracy is 0.9667
# after 155 epoch, loss =0.5712 and accuracy is 0.9800
# after 156 epoch, loss =0.5753 and accuracy is 0.9733
# after 157 epoch, loss =0.5682 and accuracy is 0.9800
# after 158 epoch, loss =0.5701 and accuracy is 0.9800
# after 159 epoch, loss =0.5684 and accuracy is 0.9800
# after 160 epoch, loss =0.5719 and accuracy is 0.9867
# after 161 epoch, loss =0.5697 and accuracy is 0.9800
# after 162 epoch, loss =0.5715 and accuracy is 0.9800
# after 163 epoch, loss =0.5701 and accuracy is 0.9800
# after 164 epoch, loss =0.5681 and accuracy is 0.9867
# after 165 epoch, loss =0.5683 and accuracy is 0.9867
# after 166 epoch, loss =0.5697 and accuracy is 0.9800
# after 167 epoch, loss =0.5702 and accuracy is 0.9800
# after 168 epoch, loss =0.5676 and accuracy is 0.9867
# after 169 epoch, loss =0.5739 and accuracy is 0.9733
# after 170 epoch, loss =0.5709 and accuracy is 0.9800
# after 171 epoch, loss =0.5760 and accuracy is 0.9800
# after 172 epoch, loss =0.5716 and accuracy is 0.9800
# after 173 epoch, loss =0.5678 and accuracy is 0.9867
# after 174 epoch, loss =0.5732 and accuracy is 0.9733
# after 175 epoch, loss =0.5720 and accuracy is 0.9800
# after 176 epoch, loss =0.5811 and accuracy is 0.9667
# after 177 epoch, loss =0.5715 and accuracy is 0.9800
# after 178 epoch, loss =0.5712 and accuracy is 0.9867
# after 179 epoch, loss =0.5675 and accuracy is 0.9800
# after 180 epoch, loss =0.5698 and accuracy is 0.9800
# after 181 epoch, loss =0.5700 and accuracy is 0.9800
# after 182 epoch, loss =0.5674 and accuracy is 0.9867
# after 183 epoch, loss =0.5727 and accuracy is 0.9733
# after 184 epoch, loss =0.5705 and accuracy is 0.9800
# after 185 epoch, loss =0.5743 and accuracy is 0.9800
# after 186 epoch, loss =0.5721 and accuracy is 0.9800
# after 187 epoch, loss =0.5676 and accuracy is 0.9867
# after 188 epoch, loss =0.5812 and accuracy is 0.9667
# after 189 epoch, loss =0.5703 and accuracy is 0.9800
# after 190 epoch, loss =0.5772 and accuracy is 0.9800
# after 191 epoch, loss =0.5724 and accuracy is 0.9800
# after 192 epoch, loss =0.5673 and accuracy is 0.9867
# after 193 epoch, loss =0.5825 and accuracy is 0.9667
# after 194 epoch, loss =0.5704 and accuracy is 0.9800
# after 195 epoch, loss =0.5785 and accuracy is 0.9733
# after 196 epoch, loss =0.5726 and accuracy is 0.9800
# after 197 epoch, loss =0.5673 and accuracy is 0.9867
# after 198 epoch, loss =0.5832 and accuracy is 0.9667
# after 199 epoch, loss =0.5700 and accuracy is 0.9800

# %%
try:
    print(torch.argmax(y_pred[-2],dim=0))
except:
    pass
    #print(torch.argmax(y_pred[-2]))
# Out:
# tensor(2)
