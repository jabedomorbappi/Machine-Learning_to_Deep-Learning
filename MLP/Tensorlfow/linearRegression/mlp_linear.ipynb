# %%
import numpy as np 
import pandas as pd 
import torch 
import tensorflow as tf
# Out:
# 2022-09-27 16:28:39.215124: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-27 16:28:46.129667: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-09-27 16:28:46.129761: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-09-27 16:28:46.684931: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-27 16:28:54.733168: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-09-27 16:28:54.733412: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-09-27 16:28:54.733432: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
n = 100
d = 2
x = np.random.uniform(-1, 1, (n, d))

# y = w * x + b
# y = w_0 * x_0 + w_1 * x_1 + b
# y = w@x + b

weights_true = np.array([[2, -1], ]).T
bias_true = np.array([0.5])
print(x.shape, weights_true.shape, bias_true.shape)

y_true = x @ weights_true + bias_true
print(f'x: {x.shape}, weights: {weights_true.shape}, bias: {bias_true.shape}, y: {y_true.shape}')

def plot_3d(x, y, y_pred=None):
    import matplotlib.pyplot as plt
    from mpl_toolkits.mplot3d import Axes3D
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(x[:, 0], x[:, 1], y, label='underlying function')
    if y_pred is not None:
        ax.scatter(x[:, 0], x[:, 1], y_pred, label='our function')
    plt.legend()

plot_3d(x, y_true)
# Out:
# (100, 2) (2, 1) (1,)
# x: (100, 2), weights: (2, 1), bias: (1,), y: (100, 1)

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import optimizers

inputs = keras.Input(shape=(2,))
l1 = layers.Dense(10, activation='relu', name='dense_1')(inputs)
outputs = layers.Dense(1, name='regression')(l1)

model = keras.Model(inputs=inputs, outputs=outputs)
print(model.summary())
model.compile(loss='mse', optimizer=optimizers.SGD(0.1))

model.fit(x, y_true, epochs=100)
# Out:
# 2022-09-27 16:29:05.383912: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-09-27 16:29:05.477468: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-27 16:29:05.477539: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jabed-HP-Notebook): /proc/driver/nvidia/version does not exist
# 2022-09-27 16:29:05.497832: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 10)                30
#
#  regression (Dense)          (None, 1)                 11
#
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 4/4 [==============================] - 2s 5ms/step - loss: 1.6560
# Epoch 2/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8770
# Epoch 3/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3155
# Epoch 4/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1179
# Epoch 5/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0589
# Epoch 6/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0282
# Epoch 7/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0239
# Epoch 8/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0215
# Epoch 9/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0235
# Epoch 10/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0184
# Epoch 11/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0181
# Epoch 12/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0165
# Epoch 13/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0175
# Epoch 14/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0146
# Epoch 15/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0141
# Epoch 16/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0154
# Epoch 17/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0128
# Epoch 18/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0116
# Epoch 19/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0113
# Epoch 20/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0106
# Epoch 21/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0116
# Epoch 22/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0118
# Epoch 23/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0089
# Epoch 24/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0089
# Epoch 25/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0085
# Epoch 26/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0078
# Epoch 27/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 28/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0072
# Epoch 29/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0095
# Epoch 30/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0084
# Epoch 31/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0062
# Epoch 32/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0063
# Epoch 33/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0057
# Epoch 34/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0053
# Epoch 35/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0049
# Epoch 36/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0047
# Epoch 37/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 38/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 39/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 40/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 41/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 42/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 43/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 44/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0029
# Epoch 45/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 46/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 47/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 48/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 49/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 50/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 51/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 52/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 53/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 54/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 55/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 56/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 57/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 58/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0029
# Epoch 59/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 60/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 61/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 62/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 63/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 64/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 65/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 66/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 67/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 68/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 69/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 70/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 71/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0013
# Epoch 72/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 73/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 74/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 75/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 76/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 77/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 78/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 79/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 80/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 81/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 82/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 83/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 84/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 85/100
# 4/4 [==============================] - 0s 5ms/step - loss: 9.9570e-04
# Epoch 86/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 87/100
# 4/4 [==============================] - 0s 5ms/step - loss: 9.3532e-04
# Epoch 88/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.1774e-04
# Epoch 89/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.9894e-04
# Epoch 90/100
# 4/4 [==============================] - 0s 5ms/step - loss: 8.8972e-04
# Epoch 91/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 92/100
# 4/4 [==============================] - 0s 5ms/step - loss: 8.7487e-04
# Epoch 93/100
# 4/4 [==============================] - 0s 5ms/step - loss: 8.6295e-04
# Epoch 94/100
# 4/4 [==============================] - 0s 5ms/step - loss: 8.8232e-04
# Epoch 95/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4436e-04
# Epoch 96/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.9670e-04
# Epoch 97/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.3375e-04
# Epoch 98/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 99/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.4186e-04
# Epoch 100/100
# 4/4 [==============================] - 0s 5ms/step - loss: 8.2344e-04
